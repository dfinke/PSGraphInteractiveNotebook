# %%
. .\ringlattice.ps1
. ..\psgraphNB.ps1

# %% [markdown]
# ## Ring-Lattice graph
# Let’s create a Ring-Lattice graph with 10 nodes and 4 connections per node.

# %%
(Get-RingLattice (0..9) 4).Visual | Show-InNotebook -LayoutEngine Circular
# Out:
# <img src="data:image/png; base64, ..."></img>

# %%
(Get-RingLattice (0..12) 12).Visual | Show-InNotebook -LayoutEngine Circular
# Out:
# <img src="data:image/png; base64, ..."></img>

# %%
# @{size="2,2"}
2..12 | ForEach {
    (Get-RingLattice (0..$_) 2).Visual | Show-InNotebook -LayoutEngine Circular
}
# Out:
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>

# %% [markdown]
# ## Small World graphs
#
# Below are three Small World graphs with the following properties:
#
# - 20 nodes
# - 4 connections per node
# - Probabilities of 10%, 30%, and 80%

# %%
foreach ($prob in (.1,.2,.8)){
    
    $swGraph = Get-SmallWorldGraph (0..19) 4 $prob @{size='2,2'}
    $swGraph.Visual | Show-InNotebook -LayoutEngine Circular
}
# Out:
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
# <img src="data:image/png; base64, ..."></img>
